# %%
import pandas as pd
import matplotlib.pyplot as plt
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cylinders', 'displacement','horsepower',
            'weight', 'acceleration', 'model_year', 'origin', 'name'],
            na_values='?')

# %%
mpg_data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null float64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
mpg_data['mpg'].corr(mpg_data['weight'])
# Out:
# -0.831740933244335

# %%
# pairwise correlation
mpg_data.drop(['model_year', 'origin'], axis=1).corr(method='spearman')

mpg_data.drop(columns=['model_year', 'origin']).corr(method='spearman')
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.821864     -0.855692   -0.853616 -0.874947
# cylinders    -0.821864   1.000000      0.911876    0.816188  0.873314
# displacement -0.855692   0.911876      1.000000    0.876171  0.945986
# horsepower   -0.853616   0.816188      0.876171    1.000000  0.878819
# weight       -0.874947   0.873314      0.945986    0.878819  1.000000
# acceleration  0.438677  -0.474189     -0.496512   -0.658142 -0.404550
#
#               acceleration
# mpg               0.438677
# cylinders        -0.474189
# displacement     -0.496512
# horsepower       -0.658142
# weight           -0.404550
# acceleration      1.000000

# %%
mpg_data.drop(['model_year', 'origin'], axis=1).corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col5 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col2 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col3 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col4 {
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col5 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T
th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80level0_row0" class="row_heading level0 row0" >mpg</th>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col1" class="data row0 col1" >-0.78</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col2" class="data row0 col2" >-0.8</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col3" class="data row0 col3" >-0.78</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col4" class="data row0 col4" >-0.83</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row0_col5" class="data row0 col5" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80level0_row1" class="row_heading level0 row1" >cylinders</th>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col0" class="data row1 col0" >-0.78</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col2" class="data row1 col2" >0.95</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col3" class="data row1 col3" >0.84</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col4" class="data row1 col4" >0.9</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row1_col5" class="data row1 col5" >-0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80level0_row2" class="row_heading level0 row2" >displacement</th>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col0" class="data row2 col0" >-0.8</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col1" class="data row2 col1" >0.95</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col3" class="data row2 col3" >0.9</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col4" class="data row2 col4" >0.93</td>
#                         <td id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80row2_col5" class="data row2 col5" >-0.54</td>
#             </tr>
#             <tr>
#                         <th id="T_41d22d62_c32b_11e9_aaf5_ecb1d72c9a80level0_row3" class="row_heading level0

# %%
# plot correlated values
plt.rcParams['figure.figsize'] = [16, 6]

fig, ax = plt.subplots(nrows=1, ncols=3)


ax=ax.flatten()

cols = ['weight', 'horsepower', 'acceleration']
colors=['#415952', '#f35134', '#243AB5', '#243AB5']
j=0

for i in ax:
    if j==0:
        i.set_ylabel('MPG',color= 'white')
    i.scatter(mpg_data[cols[j]], mpg_data['mpg'],  alpha=0.5, color=colors[j])
    i.set_xlabel(cols[j],color= 'white')
    i.set_title('Pearson: %s'%mpg_data.corr().loc[cols[j]]['mpg'].round(2)+' Spearman: %s'%mpg_data.corr(method='spearman').loc[cols[j]]['mpg'].round(2),color= 'white')
    i.tick_params(colors= 'white')
    j+=1

plt.show()
